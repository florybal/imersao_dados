# %%
import pandas as pd

fonte = "MICRODADOS_ENEM_2019.csv"
#fonte = "MICRODADOS_ENEM_2022.csv"

dados = pd.read_csv(fonte)

dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0  190001004661    2019                  1506138                Redenção
# 1  190001004674    2019                  1504208                  Marabá
# 2  190001004722    2019                  1501402                   Belém
# 3  190001004735    2019                  1507300      São Félix do Xingu
# 4  190001004776    2019                  1500800              Ananindeua
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                15               PA        17       M                1
# 1                15               PA        23       M                1
# 2                15               PA        35       F                2
# 3                15               PA        23       F                1
# 4                15               PA        16       F                1
#
#    TP_COR_RACA  ...  Q016  Q017 Q018  Q019 Q020  Q021  Q022  Q023  Q024  Q025
# 0            3  ...     A     A    A     A    B     A     C     A     B     B
# 1            3  ...     A     A    A     B    A     A     B     A     A     B
# 2            1  ...     A     A    A     B    A     B     B     A     A     B
# 3            3  ...     A     A    A     B    A     A     B     A     A     B
# 4            3  ...     A     A    A     B    A     A     D     A     A     B
#
# [5 rows x 136 columns]

# %%
dados.shape
#linhas, colunas
# Out:
# (127380, 136)

# %%
dados.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
#        'IN_SEM_RECURSO', 'IN_BRAILLE', 'IN_AMPLIADA_24', 'IN_AMPLIADA_18',
#        'IN_LEDOR', 'IN_ACESSO', 'IN_TRANSCRICAO', 'IN_LIBRAS',
#        'IN_TEMPO_ADICIONAL', 'IN_LEITURA_LABIAL', 'IN_MESA_CADEIRA_RODAS',
#        'IN_MESA_CADEIRA_SEPARADA', 'IN_APOIO_PERNA', 'IN_GUIA_INTERPRETE',
#        'IN_COMPUTADOR', 'IN_CADEIRA_ESPECIAL', 'IN_CADEIRA_CANHOTO',
#        'IN_CADEIRA_ACOLCHOADA', 'IN_PROVA_DEITADO', 'IN_MOBILIARIO_OBESO',
#        'IN_LAMINA_OVERLAY', 'IN_PROTETOR_AURICULAR', 'IN_MEDIDOR_GLICOSE',
#        'IN_MAQUINA_BRAILE', 'IN_SOROBAN', 'IN_MARCA_PASSO', 'IN_SONDA',
#        'IN_MEDICAMENTOS', 'IN_SALA_INDIVIDUAL', 'IN_SALA_ESPECIAL',
#        'IN_SALA_ACOMPANHANTE', 'IN_MOBILIARIO_ESPECIFICO',
#        'IN_MATERIAL_ESPECIFICO', 'IN_NOME_SOCIAL', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
#        'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
#        'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
#        'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
#        'Q023', 'Q024', 'Q025'], dtype=object)

# %%
dados[["NU_IDADE", "NU_NOTA_COMP2"]]
# Out:
#         NU_IDADE  NU_NOTA_COMP2
# 0             17          100.0
# 1             23          100.0
# 2             35          120.0
# 3             23          120.0
# 4             16          140.0
# ...          ...            ...
# 127375        17          160.0
# 127376        18          120.0
# 127377        22          120.0
# 127378        26          120.0
# 127379        19          120.0
#
# [127380 rows x 2 columns]

# %%
dados["SG_UF_RESIDENCIA"].unique()
# Out:
# array(['PA', 'RO', 'MT', 'AC', 'AM', 'RR', 'MA', 'PR', 'BA', 'PI', 'CE',
#        'PE', 'AP', 'TO', 'SC', 'GO', 'MG', 'SP', 'SE', 'RJ', 'PB', 'AL',
#        'RN', 'ES', 'DF', 'RS', 'MS'], dtype=object)

# %%
len(dados["SG_UF_RESIDENCIA"].unique())
# Out:
# 27

# %%
dados["SG_UF_RESIDENCIA"].value_counts()
# Out:
# SG_UF_RESIDENCIA
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: count, dtype: int64

# %%
dados["NU_IDADE"].value_counts().sort_index()
# Out:
# NU_IDADE
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: count, Length: 65, dtype: int64

# %%
#desafio 1
#proporção dos inscritos por idade
dados["NU_IDADE"].value_counts()
# Out:
# NU_IDADE
# 18    21452
# 17    21256
# 19    14418
# 20    10413
# 16     7830
#       ...
# 73        2
# 75        2
# 77        1
# 82        1
# 76        1
# Name: count, Length: 65, dtype: int64

# %%
#desafio 2
#Descobrir quais estados são incritos com 13 anos
dados[["NU_IDADE", "SG_UF_RESIDENCIA"]].value_counts().sort_index()
# Out:
# NU_IDADE  SG_UF_RESIDENCIA
# 13        AP                  1
#           BA                  1
#           MT                  1
#           SP                  1
# 14        AC                  1
#                              ..
# 73        SP                  1
# 75        BA                  2
# 76        BA                  1
# 77        RJ                  1
# 82        RJ                  1
# Name: count, Length: 1333, dtype: int64

# %%
dados["NU_IDADE"].hist()
# Out:
# <Axes: >

# %%
dados["NU_IDADE"].hist(bins=20, figsize=(10, 8))
# Out:
# <Axes: >

# %%
#desafio 3
#adiconar titulo no grafico

dados["NU_IDADE"].hist(bins=20, title='test')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 4
#       1 #desafio 3
#       2 #adiconar titulo no grafico
# ----> 4 dados["NU_IDADE"].hist(bins=20, title='test')
#
# File ~/.local/share/virtualenvs/2020-mJbQJ2ND/lib/python3.9/site-packages/pandas/plotting/_core.py:125, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      58 """
#      59 Draw histogram of the input series using matplotlib.
#      60
#    (...)
#     122     >>> hist = ser.groupby(level=0).hist()
#     123 """
#     124 plot_backend = _get_plot_backend(backend)
# --> 125 return plot_backend.hist_series(
#     126     self,
#     127     by=by,
#     128     ax=ax,
#     129     grid=grid,
#     130     xlabelsize=xlabelsize,
#     131     xrot=xrot,
#     132     ylabelsize=ylabelsize,
#     133     yrot=yrot,
#     134     figsize=figsize,
#     135     bins=bins,
#     136     legend=legend,
#     137     **kwargs,
#     138 )
#
# File ~/.local/share/virtualenvs/2020-mJbQJ2ND/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py:427, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, legend, **kwds)
#     425 if legend:
#     426     kwds["label"] = self.name
# --> 427 ax.hist(values, bins=bins, **kwds)
#     428 if legend:
#     429     ax.legend()
#
# File ~/.local/share/virtualenvs/2020-mJbQJ2ND/lib/python3.9/site-packages/matplotlib/__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File ~/.local/share/virtualenvs/2020-mJbQJ2ND/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6944, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6942 if patch:
#    6943     p = patch[0]
# -> 6944     p._internal_update(kwargs)
#    6945     if lbl is not None:
#    6946         p.set_label(lbl)
#
# File ~/.local/share/virtualenvs/2020-mJbQJ2ND/lib/python3.9/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~/.local/share/virtualenvs/2020-mJbQJ2ND/lib/python3.9/site-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'title'

# %%
dados.query("IN_TREINEIRO == 1")
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0       190001004661    2019                  1506138                Redenção
# 4       190001004776    2019                  1500800              Ananindeua
# 12      190001005076    2019                  1506138                Redenção
# 14      190001005081    2019                  1506807                Santarém
# 16      190001005202    2019                  1502301            Capitão Poço
# ...              ...     ...                      ...                     ...
# 127328  190006117441    2019                  3126752          Franciscópolis
# 127340  190006117776    2019                  4305108           Caxias do Sul
# 127349  190006118483    2019                  2511301                  Piancó
# 127350  190006118551    2019                  2611606                  Recife
# 127352  190006118561    2019                  2600807                 Altinho
#
#         CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                     15               PA        17       M                1
# 4                     15               PA        16       F                1
# 12                    15               PA        15       M                1
# 14                    15               PA        17       F                1
# 16                    15               PA        17       F                1
# ...                  ...              ...       ...     ...              ...
# 127328                31               MG        16       M                3
# 127340                43               RS        17       F                1
# 127349                25               PB        15       F                1
# 127350                26               PE        16       M                1
# 127352                26               PE        18       M                1
#
#         TP_COR_RACA  ...  Q016  Q017 Q018  Q019 Q020  Q021  Q022  Q023  Q024  \
# 0                 3  ...     A     A    A     A    B     A     C     A     B
# 4                 3  ...     A     A    A     B    A     A     D     A     A
# 12                3  ...     B     A    A     B    B     A     C     A     A
# 14                3  ...     A     A    A     B    A     A     D     A     A
# 16                3  ...     B     A    A     B    B     A     C     A     A
# ...             ...  ...   ...   ...  ...   ...  ...   ...   ...   ...   ...
# 127328            3  ...     A     A    A     B    A     A     D     A     A
# 127340            1  ...     B     A    B     A    A     A     C     A     C
# 127349            1  ...     A     A    A     B    A     A     B     A     A
# 127350            1  ...     B     A    B     E    B     B     E     B     B
# 127352            3  ...     A     A    A     B    A     A     B     A     A
#
#         Q025
# 0          B
# 4          B
# 12         B
# 14         B
# 16         A
# ...      ...
# 127328     B
# 127340     B
# 127349     A
# 127350     B
# 127352     B
#
# [15401 rows x 136 columns]

# %%
dados.query("IN_TREINEIRO == 1")["NU_IDADE"].value_counts().sort_index()
# Out:
# NU_IDADE
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: count, dtype: int64
